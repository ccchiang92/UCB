# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# 1. There is a strong correlation between average tumor size and mouse weight
# 2. Capomulin and Ramicane seems promisming at reducing tumor size, while most other drugs don't seem to reduce tumor size
# 3. Most drugs had comparable amount of data points, only the two tumor reducing drugs had significantly extra data points
# 4. The data contains very similar amount of female mice and male mice
# 5. Of the four promising treatment regimens the effective drugs's final tumor volume, Capomulin and Ramicane have a bigger spread while the other 2 drugs have a denser distribution. However, none of them had outliers

# %% [markdown]
# ## Dependencies and starter code

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)

# Combine the data into a single dataset
combine_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")


combine_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %% [markdown]
# ## Summary statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Group Tumor volume measurements for each timepoint and drug
combine_gb = combine_df.groupby(["Drug Regimen", "Timepoint"])[
    "Tumor Volume (mm3)"]

# Calculate the relevent statistics with panda methods then re-format them for table construction
mean_gb = combine_gb.mean().to_frame().reset_index().groupby("Drug Regimen")
median_gb = combine_gb.median().to_frame().reset_index().groupby("Drug Regimen")
std_gb = combine_gb.std().to_frame().reset_index().groupby("Drug Regimen")
var_gb = combine_gb.var().to_frame().reset_index().groupby("Drug Regimen")
sem_gb = combine_gb.sem().to_frame().reset_index().groupby("Drug Regimen")

# For each drug create a stat summary table using tables generated above and store into a dictionary called sum_tables where key is the drug name
sum_tables = {}
for drug in mean_gb.groups:
    # Creating a temporary DF
    cur_drug_df = pd.DataFrame()
    # For each stat create a new column using data only for the current drug
    cur_drug_df["Mean"] = mean_gb.get_group(drug).set_index("Timepoint")[
        "Tumor Volume (mm3)"]
    cur_drug_df["Median"] = median_gb.get_group(drug).set_index("Timepoint")[
        "Tumor Volume (mm3)"]
    cur_drug_df["Variance"] = var_gb.get_group(drug).set_index("Timepoint")[
        "Tumor Volume (mm3)"]
    cur_drug_df["Standard Deviation"] = std_gb.get_group(
        drug).set_index("Timepoint")["Tumor Volume (mm3)"]
    cur_drug_df["SEM"] = sem_gb.get_group(drug).set_index("Timepoint")[
        "Tumor Volume (mm3)"]
    # Store temporary DF into dictionary
    sum_tables[drug] = cur_drug_df
    # Print each table
    print(drug + " Summary Table")
    print(cur_drug_df)
    print("-"*40)
# Out:
# Capomulin Summary Table
#                 Mean     Median   Variance  Standard Deviation       SEM
# Timepoint
# 0          45.000000  45.000000   0.000000            0.000000  0.000000
# 5          44.266086  45.597064   5.030889            2.242964  0.448593
# 10         43.084291  43.421014  12.344133            3.513422  0.702684
# 15         42.064317  42.798160  16.878693            4.108369  0.838617
# 20         40.716325  40.716428  19.035028            4.362915  0.909731
# 25         39.939528  40.224165  17.100444            4.135268  0.881642
# 30         38.769339  39.260371  19.210721            4.383004  0.934460
# 35         37.816839  38.360455  24.358640            4.935447  1.052241
# 40         36.958001  36.843898  31.441568            5.607278  1.223608
# 45         36.236114  37.311846  31.460537            5.608969  1.223977
# ----------------------------------------
# Ceftamin Summary Table
# ...

# %% [markdown]
# ## Bar plots

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas
# Create a list of drug regimen for labeling
drug_names = list(sum_tables.keys())
drug_num = len(drug_names)
# create a color list for each drug
color_list = ["C" + str(i) for i in range(drug_num)]
# Plot a bar graph by calling pandas plot menthods on a organized dataframe
pd_bar = combine_df.groupby("Drug Regimen")["Mouse ID"].count().plot.bar(
    color=color_list, rot=45, width=0.55)
# Aesthetics adjustments
pd_bar.set_title("Data Points per Drug by pandas")
pd_bar.set_xlabel("Drug Regimens")
pd_bar.set_ylabel("Number of Data points")
pd_bar.set_ylim(0, combine_df.groupby("Drug Regimen")
                ["Mouse ID"].count().max() + 10)
pd_bar.set_xlim(-0.5, drug_num - 0.5)
# Out:
# (-0.5, 9.5)

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pyplot
# Using matplotlib.pyplot plotting methods
# Passing in a list of drug names for labels and a pandas series for the height
fig_bar, ax_bar = plt.subplots()
ax_bar.bar(drug_names, combine_df.groupby("Drug Regimen")[
           "Mouse ID"].count(), color=color_list, width=0.55)
# Aesthetics adjustments to match the previous graph
plt.xticks(rotation=45)
ax_bar.set_title("Data Points per Drug by pyplot")
ax_bar.set_xlabel("Drug Regimens")
ax_bar.set_ylabel("Number of Data points")
ax_bar.set_ylim(0, combine_df.groupby("Drug Regimen")
                ["Mouse ID"].count().max() + 10)
ax_bar.set_xlim(-0.5, drug_num - 0.5)
# Out:
# (-0.5, 9.5)

# %% [markdown]
# ## Pie plots

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
# Only intrested in each mouse once so creating a new DF dropping all duplicate mouse ids
pie_unique_ID = combine_df.drop_duplicates("Mouse ID")
# Tally the sex of mouses
sex_count = pie_unique_ID["Sex"].value_counts()

# Plot by calling pandas method, include aesthetics into the plot call
pie_panda = sex_count.plot.pie(legend=True, subplots=True, autopct="%1.1f%%", shadow=True, startangle=45, colors=[
                               'C0', 'C6'], title='Mouse Sex Distribution by pandas')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Plot the same sex count data using matplot
fig_pie, ax_pie = plt.subplots()
ax_pie.pie(sex_count, labels=pie_unique_ID['Sex'].unique(),
           autopct="%1.1f%%", shadow=True, startangle=45, colors=['C0', 'C6'])
# Set same aesthetics as the panda plot
ax_pie.set_title("Mouse Sex Distribution by pyplot")
ax_pie.legend(loc="best")
ax_pie.set_ylabel('Sex')
# Out:
# Text(0, 0.5, 'Sex')

# %% [markdown]
# ## Quartiles, outliers and boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. Calculate the IQR and quantitatively determine if there are any potential outliers.
# Create a list of relevent drugs
promising = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Construct tables for each drug only containing data from the respective drug and final timepoint
box_tables = {}
for drug in promising:
    cur_table = combine_df.loc[(combine_df["Drug Regimen"] == drug) & (
        combine_df["Timepoint"] == combine_df["Timepoint"].max())]
    # Store the new tables into a dictionary
    box_tables[drug] = cur_table
# For each drug, calculate the IQR, lower and upper bound
for drug, table in box_tables.items():
    cur_tab_volume = table["Tumor Volume (mm3)"]
    q1, q2, q3 = cur_tab_volume.quantile([.25, .5, .75])
    IQR = q3 - q1
    lower_limit = q1 - (1.5 * IQR)
    upper_limit = q3 + (1.5 * IQR)
    print(f"IQR for {drug} is {IQR}")
    # Using loc generate a table that contains only the row of outliers
    outlier_tab = cur_tab_volume.loc[(
        cur_tab_volume > upper_limit) | (cur_tab_volume < lower_limit)]
    outlier_num = len(outlier_tab)
    # The length of outlier_tab will tell us how many outliers there are
    if outlier_num > 0:
        print(f"There are {outlier_num} outliers found for {drug}")
        print('-'*40)
    else:
        print(f"No outliers were found for {drug}")
        print('-'*40)
# Out:
# IQR for Capomulin is 7.781863460000004
# No outliers were found for Capomulin
# ----------------------------------------
# IQR for Ramicane is 7.527130082499998
# No outliers were found for Ramicane
# ----------------------------------------
# IQR for Infubinol is 4.9311172099999965
# No outliers were found for Infubinol
# ----------------------------------------
# IQR for Ceftamin is 6.093590140000003
# No outliers were found for Ceftamin
# ----------------------------------------

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# Create a list of series where each series represent the final tumor volumes for a regimen
# Want to create a seperate box for each series
tumor_volumes = [table["Tumor Volume (mm3)"]
                 for drug, table in box_tables.items()]
# Plot all boxes into one plot
fig_box, ax_box = plt.subplots()
ax_box.boxplot(tumor_volumes, labels=promising)
ax_box.set_ylabel('Final Tumor volume (mm3)')
ax_box.set_title('Promising Drugs Box Plot')

# # Alternativly the following code will plot each drug into its own subplot
# num_drugs = len(promising)
# fig_box, ax_box= plt.subplots(1, num_drugs, figsize=(15,6))
# i= 0
# for drug, table in box_tables.items():
#     ax_box[i].boxplot(table["Tumor Volume (mm3)"])
#     ax_box[i].set_ylabel('Final Tumor volume (mm3)')
#     ax_box[i].set_title(f'{drug} Box Plot')
#     ax_box[i].set_xlabel(str(drug))
#     ax_box[i].set_ylim(20,75)
#     i += 1
# Out:
# Text(0.5, 1.0, 'Promising Drugs Box Plot')

# %% [markdown]
# ## Line and scatter plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
# Pick a mouse ID
mouse_to_plot = "b128"
# Grab data from only our mouse and capomulin
mouse_df = combine_df.loc[(combine_df["Drug Regimen"] == "Capomulin") & (
    combine_df["Mouse ID"] == mouse_to_plot)]
# Plot using pandas giving column timepoint as x and tumor size as y
mouse_line_plot = mouse_df.plot(
    "Timepoint", "Tumor Volume (mm3)", label=f"Mouse {mouse_to_plot}")
# Set axis and title
mouse_line_plot.set_title(
    f"Mouse {mouse_to_plot}\'s Tumor Size V.S. Time with Capomulin")
mouse_line_plot.set_xlabel("Time Points")
mouse_line_plot.set_ylabel("Tumor Size in mm3")
# Out:
# Text(0, 0.5, 'Tumor Size in mm3')

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
# Grab data for only Capomulin
scatter_df = combine_df.loc[combine_df["Drug Regimen"] == "Capomulin"]
# Caculate average tumor size for each mouse, sort to ensure data aligns
avg_tumor = scatter_df.groupby(
    "Mouse ID")["Tumor Volume (mm3)"].mean().sort_index()
# Since mouse wieght stay costant for each mouse, create a weight list by dropping duplicates
# Sort by mouse ID to align data
mouse_weight = scatter_df.drop_duplicates("Mouse ID").set_index('Mouse ID')[
    'Weight (g)'].sort_index()
# Scatter plot with pyplot
plt.scatter(mouse_weight, avg_tumor, facecolors="blue", edgecolors="black")
# Titles and labels
plt.title("Mouse Weight vs Average Tumor Volume for Capomulin")
plt.xlabel("Mouse Weight in g")
plt.ylabel("Average Tumor Size in mm3")
# Out:
# Text(0, 0.5, 'Average Tumor Size in mm3')

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
# Calculate liner regression using scipy.stats package
slope, intercept, rvalue, pvalue, stderr = st.linregress(
    mouse_weight, avg_tumor)
print(
    'Correlation coefficent for mouse weight and average tumor volume is {0:.4f}'.format(rvalue))
print(
    'The linear regression model is y = {0:.4f} * x + {1:.4f}'.format(slope, intercept))

# Generate data points for line using the equation above
lin_x = np.arange(mouse_weight.min()-1, mouse_weight.max()+1, 1)
lin_y = (lin_x * slope) + intercept
# Replot the data points
plt.scatter(mouse_weight, avg_tumor, facecolors="blue",
            edgecolors="black", label='Weight vs Volume Data Points')
# Plot the regression line
plt.plot(lin_x, lin_y, 'r--',
         label='y = {0:.3f} * x + {1:.3f}'.format(slope, intercept))
# Aesthetics
plt.title("Mouse Weight vs Average Tumor Volume for Capomulin")
plt.xlabel("Mouse Weight in g")
plt.ylabel("Average Tumor Size in mm3")
plt.legend(loc='best')
# Out:
# Correlation coefficent for mouse weight and average tumor volume is 0.8419
# The linear regression model is y = 0.9544 * x + 21.5522

# %%
# Out:
# 25
